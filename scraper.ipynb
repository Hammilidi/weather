# %%
# %pip install pyowm
# Out:
# Collecting pyowm
#   Downloading pyowm-3.3.0-py3-none-any.whl (4.5 MB)
#      ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.5 MB 245.8 kB/s eta 0:00:19
#       --------------------------------------- 0.1/4.5 MB 326.8 kB/s eta 0:00:14
#      - -------------------------------------- 0.1/4.5 MB 514.3 kB/s eta 0:00:09
#      - -------------------------------------- 0.2/4.5 MB 808.4 kB/s eta 0:00:06
#      - -------------------------------------- 0.2/4.5 MB 808.4 kB/s eta 0:00:06
#      -- ------------------------------------- 0.3/4.5 MB 714.4 kB/s eta 0:00:07
#      -- ------------------------------------- 0.3/4.5 MB 679.3 kB/s eta 0:00:07
#      --- ------------------------------------ 0.4/4.5 MB 807.8 kB/s eta 0:00:06
#      --- ------------------------------------ 0.5/4.5 MB 880.6 kB/s eta 0:00:05
#      ---- ----------------------------------- 0.5/4.5 MB 981.7 kB/s eta 0:00:05
#      ----- ---------------------------------- 0.6/4.5 MB 1.0 MB/s eta 0:00:04
#      ----- ---------------------------------- 0.7/4.5 MB 1.0 MB/s eta 0:00:04
#      ------ --------------------------------- 0.7/4.5 MB 989.1 kB/s eta 0:00:04
#      ------ --------------------------------- 0.8/4.5 MB 1.0 MB/s eta 0:00:04
#      ------ --------------------------------- 0.8/4.5 MB 1.0 MB/s eta 0:00:04
#      ------ --------------------------------- 0.8/4.5 MB 1.0 MB/s eta 0:00:04
#      ------ --------------------------------- 0.8/4.5 MB 1.0 MB/s eta 0:00:04
#      ------ --------------------------------- 0.8/4.5 MB 1.0 MB/s eta 0:00:04
#      ------- -------------------------------- 0.9/4.5 MB 894.0 kB/s eta 0:00:05
#      -------- ------------------------------- 1.0/4.5 MB 912.9 kB/s eta 0:00:04
#      --------- ------------------------------ 1.1/4.5 MB 977.5 kB/s eta 0:00:04
#      --------- ------------------------------ 1.1/4.5 MB 1.0 MB/s eta 0:00:04
#      --------- ------------------------------ 1.1/4.5 MB 1.0 MB/s eta 0:00:04
#      --------- ------------------------------ 1.1/4.5 MB 1.0 MB/s eta 0:00:04
#      ---------- ----------------------------- 1.2/4.5 MB 933.9 kB/s eta 0:00:04
#      ---------- ----------------------------- 1.2/4.5 MB 933.9 kB/s eta 0:00:04
#      ---------- ----------------------------- 1.2/4.5 MB 865.9 kB/s eta 0:00:04
#      ---------- ----------------------------- 1.2/4.5 MB 865.9 kB/s eta 0:00:04
#      ---------- ----------------------------- 1.2/4.5 MB 824.0 kB/s eta 0:00:05
#      ---------- ----------------------------- 1.2/4.5 MB 803.8 kB/s eta 0:00:05
#      ----------- ---------------------------- 1.3/4.5 MB 815.5 kB/s eta 0:00:05
#      ----------- ---------------------------- 1.3/4.5 MB 815.5 kB/s eta 0:00:05
#      ----------- ---------------------------- 1.3/4.5 MB 760.1 kB/s eta 0:00:05
#      ----------- ---------------------------- 1.3/4.5 MB 760.1 kB/s eta 0:00:05
#      ----------- ---------------------------- 1.3/4.5 MB 731.4 kB/s eta 0:00:05
#      ----------- ---------------------------- 1.3/4.5 MB 730.6 kB/s eta 0:00:05
#      ----------- ---------------------------- 1.3/4.5 MB 716.4 kB/s eta 0:00:05
#      ----------- ---------------------------- 1.3/4.5 MB 716.4 kB/s eta 0:00:05
#      ----------- ---------------------------- 1.4/4.5 MB 692.2 kB/s eta 0:00:05
#      ------------ --------------------------- 1.4/4.5 MB 706.7 kB/s eta 0:00:05
#      ------------ --------------------------- 1.4/4.5 MB 711.1 kB/s eta 0:00:05
#      ------------- -------------------------- 1.5/4.5 MB 738.8 kB/s eta 0:00:05
#      ------------- -------------------------- 1.6/4.5 MB 737.3 kB/s eta 0:00:05
#      -------------- ------------------------- 1.7/4.5 MB 767.5 kB/s eta 0:00:04
#      --------------- ------------------------ 1.8/4.5 MB 807.6 kB/s eta 0:00:04
#      ---------------- ----------------------- 1.9/4.5 MB 830.1 kB/s eta 0:00:04
#      ------------------ --------------------- 2.0/4.5 MB 875.0 kB/s eta 0:00:03
#      ------------------ --------------------- 2.1/4.5 MB 880.8 kB/s eta 0:00:03
#      ------------------- -------------------- 2.2/4.5 MB 917.5 kB/s eta 0:00:03
#      --------------------- ------------------ 2.4/4.5 MB 974.6 kB/s eta 0:00:03
#      ---------------------- ----------------- 2.5/4.5 MB 993.1 kB/s eta 0:00:03
#      ----------------------- ---------------- 2.6/4.5 MB 1.0 MB/s eta 0:00:02
#      ------------------------ --------------- 2.8/4.5 MB 1.1 MB/s eta 0:00:02
#      ------------------------- -------------- 2.9/4.5 MB 1.1 MB/s eta 0:00:02
#      ------------------------- -------------- 2.9/4.5 MB 1.1 MB/s eta 0:00:02
#      -------------------------- ------------- 3.0/4.5 MB 1.1 MB/s eta 0:00:02
#      ---------------------------- ----------- 3.2/4.5 MB 1.1 MB/s eta 0:00:02
#      ----------------------------- ---------- 3.3/4.5 MB 1.1 MB/s eta 0:00:02
#      ------------------------------ --------- 3.5/4.5 MB 1.2 MB/s eta 0:00:01
#      ------------------------------ --------- 3.5/4.5 MB 1.2 MB/s eta 0:00:01
#      ------------------------------ --------- 3.5/4.5 MB 1.2 MB/s eta 0:00:01
#      ------------------------------ --------- 3.5/4.5 MB 1.2 MB/s eta 0:00:01
#      ------------------------------ --------- 3.5/4.5 MB 1.2 MB/s eta 0:00:01
#      ------------------------------ --------- 3.5/4.5 MB 1.2 MB/s eta 0:00:01
#      ------------------------------ --------- 3.5/4.5 MB 1.2 MB/s eta 0:00:01
#      ------------------------------ --------- 3.5/4.5 MB 1.1 MB/s eta 0:00:01
#      ------------------------------- -------- 3.5/4.5 MB 1.1 MB/s eta 0:00:01
#      ------------------------------- -------- 3.5/4.5 MB 1.1 MB/s eta 0:00:01
#      ------------------------------- -------- 3.5/4.5 MB 1.1 MB/s eta 0:00:01
#      ------------------------------- -------- 3.5/4.5 MB 1.1 MB/s eta 0:00:01
#      ------------------------------- -------- 3.6/4.5 MB 1.0 MB/s eta 0:00:01
#      -------------------------------- ------- 3.7/4.5 MB 1.0 MB/s eta 0:00:01
#      -------------------------------- ------- 3.7/4.5 MB 1.0 MB/s eta 0:00:01
#      ---------------------------------- ----- 3.9/4.5 MB 1.1 MB/s eta 0:00:01
#      ---------------------------------- ----- 3.9/4.5 MB 1.1 MB/s eta 0:00:01
#      ---------------------------------- ----- 3.9/4.5 MB 1.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 4.0/4.5 MB 1.1 MB/s eta 0:00:01
#      ------------------------------------ --- 4.2/4.5 MB 1.1 MB/s eta 0:00:01
#      ------------------------------------ --- 4.2/4.5 MB 1.1 MB/s eta 0:00:01
#      ------------------------------------- -- 4.3/4.5 MB 1.1 MB/s eta 0:00:01
#      ------------------------------------- -- 4.3/4.5 MB 1.1 MB/s eta 0:00:01
#      -------------------------------------- - 4.4/4.5 MB 1.1 MB/s eta 0:00:01
#      ---------------------------------------  4.5/4.5 MB 1.1 MB/s eta 0:00:01
#      ---------------------------------------  4.5/4.5 MB 1.1 MB/s eta 0:00:01
#      ---------------------------------------  4.5/4.5 MB 1.1 MB/s eta 0:00:01
#      ---------------------------------------- 4.5/4.5 MB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.20.0 in c:\users\user\anaconda3\lib\site-packages (from pyowm) (2.31.0)
# Collecting geojson<3,>=2.3.0 (from pyowm)
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: PySocks<2,>=1.7.1 in c:\users\user\anaconda3\lib\site-packages (from pyowm) (1.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.20.0->pyowm) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.20.0->pyowm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.20.0->pyowm) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.20.0->pyowm) (2023.7.22)
# Installing collected packages: geojson, pyowm
# Successfully installed geojson-2.5.0 pyowm-3.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install csv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement csv (from versions: none)
# ERROR: No matching distribution found for csv

# %%
# %pip install datetime
# Out:
# Collecting datetime
#   Obtaining dependency information for datetime from https://files.pythonhosted.org/packages/95/88/3b9d4042b396221a132180b392ab2a174031a6fb579f7927f3909fc183a7/DateTime-5.2-py3-none-any.whl.metadata
#   Downloading DateTime-5.2-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: zope.interface in c:\users\user\anaconda3\lib\site-packages (from datetime) (5.4.0)
# Requirement already satisfied: pytz in c:\users\user\anaconda3\lib\site-packages (from datetime) (2023.3.post1)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from zope.interface->datetime) (68.0.0)
# Downloading DateTime-5.2-py3-none-any.whl (52 kB)
#    ---------------------------------------- 0.0/52.2 kB ? eta -:--:--
#    ------- -------------------------------- 10.2/52.2 kB ? eta -:--:--
#    ---------------------------------------- 52.2/52.2 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: datetime
# Successfully installed datetime-5.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# %pip install requestsimport requests

# %% [markdown]
# ## Données actuelles

# %%
import requests

# Remplacez 'YOUR_API_KEY' par votre clé API OpenWeather
api_key = '37e333ac92209e27137831ba501a0c03'

# Liste de villes au Maroc pour lesquelles vous souhaitez obtenir des données météorologiques
cities = ['Casablanca', 'Rabat', 'Marrakech', 'Fes', 'Tangier']

# Code de pays pour le Maroc
country_code = 'MA'

# Parcourez la liste de villes et effectuez des requêtes pour chaque ville
for city in cities:
    # URL de l'endpoint de l'API pour les données météorologiques actuelles
    url = f'http://api.openweathermap.org/data/2.5/weather?q={city},{country_code}&appid={api_key}'

    # Effectuez la requête HTTP pour obtenir les données météorologiques actuelles
    response = requests.get(url)

    # Vérifiez la réponse
    if response.status_code == 200:
        data = response.json()
        # Les données météorologiques actuelles sont stockées dans 'data'
        print(f'Données météorologiques pour {city}:')
        print('Température (en °C):', data['main']['temp'])
        print('Conditions météorologiques:', data['weather'][0]['description'])
        print('Humidité:', data['main']['humidity'], '%')
        print('Vitesse du vent (en m/s):', data['wind']['speed'])
        print('\n')
    else:
        print(f'Erreur pour {city}: {response.status_code}')
# Out:
# Données météorologiques pour Casablanca:
# Température (en °C): 294.12
# Conditions météorologiques: few clouds
# Humidité: 77 %
# Vitesse du vent (en m/s): 3.09
#
#
# Données météorologiques pour Rabat:
# Température (en °C): 293.21
# Conditions météorologiques: few clouds
# Humidité: 87 %
# Vitesse du vent (en m/s): 1.54
#
#
# Données météorologiques pour Marrakech:
# Température (en °C): 298.19
# Conditions météorologiques: clear sky
# Humidité: 47 %
# Vitesse du vent (en m/s): 1.54
#
#
# Données météorologiques pour Fes:
# Température (en °C): 293.29
# Conditions météorologiques: scattered clouds
# Humidité: 82 %
# Vitesse du vent (en m/s): 1.54
#
#
# Données météorologiques pour Tangier:
# Température (en °C): 291.79
# Conditions météorologiques: clear sky
# Humidité: 88 %
# Vitesse du vent (en m/s): 1.54

# %% [markdown]
# ## Prévisions

# %%
import requests
from datetime import datetime

# Remplacez 'YOUR_API_KEY' par votre clé API OpenWeather
api_key = '37e333ac92209e27137831ba501a0c03'

# Liste de villes au Maroc pour lesquelles vous souhaitez obtenir des données météorologiques
cities = ['Casablanca', 'Rabat', 'Marrakech', 'Fes', 'Tangier']

# Code de pays pour le Maroc
country_code = 'MA'

# Nombre de jours de prévision souhaité
num_days = 5

# Parcourez la liste de villes et effectuez des requêtes pour chaque ville
for city in cities:
    # URL de l'endpoint de l'API pour les prévisions météorologiques
    url = f'http://api.openweathermap.org/data/2.5/forecast?q={city},{country_code}&appid={api_key}'

    # Effectuez la requête HTTP pour obtenir les données de prévision
    response = requests.get(url)

    # Vérifiez la réponse
    if response.status_code == 200:
        data = response.json()
        # Les données de prévision sont stockées dans 'data'
        print(f'Prévisions météorologiques pour {city} pour les prochains {num_days} jours:')
        for forecast in data['list'][:num_days]:
            # Date de la prévision
            timestamp = forecast['dt']
            date = datetime.utcfromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S')
            print(f'Date: {date}')
            # Les autres informations météorologiques pour cette date
            print(f'Données météorologiques: {forecast}')
            print('\n')
    else:
        print(f'Erreur pour {city}: {response.status_code}')
# Out:
# Prévisions météorologiques pour Casablanca pour les prochains 5 jours:
# Date: 2023-11-01 21:00:00
# Données météorologiques: {'dt': 1698872400, 'main': {'temp': 293.89, 'feels_like': 293.98, 'temp_min': 293.43, 'temp_max': 293.89, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 1019, 'humidity': 75, 'temp_kf': 0.46}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'clouds': {'all': 13}, 'wind': {'speed': 3.05, 'deg': 40, 'gust': 3.93}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-01 21:00:00'}
#
#
# Date: 2023-11-02 00:00:00
# Données météorologiques: {'dt': 1698883200, 'main': {'temp': 293.29, 'feels_like': 293.32, 'temp_min': 292.88, 'temp_max': 293.29, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 1018, 'humidity': 75, 'temp_kf': 0.41}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 7}, 'wind': {'speed': 2.01, 'deg': 47, 'gust': 2.55}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-02 00:00:00'}
#
#
# Date: 2023-11-02 03:00:00
# Données météorologiques: {'dt': 1698894000, 'main': {'temp': 292.48, 'feels_like': 292.4, 'temp_min': 292.48, 'temp_max': 292.48, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 1017, 'humidity': 74, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 1.56, 'deg': 30, 'gust': 2.09}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-02 03:00:00'}
#
#
# Date: 2023-11-02 06:00:00
# Données météorologiques: {'dt': 1698904800, 'main': {'temp': 292.04, 'feels_like': 291.92, 'temp_min': 292.04, 'temp_max': 292.04, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 1017, 'humidity': 74, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 0.55, 'deg': 297, 'gust': 0.87}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-02 06:00:00'}
#
#
# Date: 2023-11-02 09:00:00
# Données météorologiques: {'dt': 1698915600, 'main': {'temp': 293.52, 'feels_like': 293.34, 'temp_min': 293.52, 'temp_max': 293.52, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 1018, 'humidity': 66, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'clouds': {'all': 0}, 'wind': {'speed': 2.85, 'deg': 219, 'gust': 3.18}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2023-11-02 09:00:00'}
#
#
# Prévisions météorologiques pour Rabat pour les prochains 5 jours:
# Date: 2023-11-01 21:00:00
# Données météorologiques: {'dt': 1698872400, 'main': {'temp': 292.95, 'feels_like': 293.15, 'temp_min': 292.43, 'temp_max': 292.95, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 1013, 'humidity': 83, 'temp_kf': 0.52}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'clouds': {'all': 13}, 'wind': {'speed': 2.25, 'deg': 42, 'gust': 2.51}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-01 21:00:00'}
#
#
# Date: 2023-11-02 00:00:00
# Données météorologiques: {'dt': 1698883200, 'main': {'temp': 292.27, 'feels_like': 292.27, 'temp_min': 291.8, 'temp_max': 292.27, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 1012, 'humidity': 78, 'temp_kf': 0.47}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 7}, 'wind': {'speed': 1.23, 'deg': 68, 'gust': 1.31}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-02 00:00:00'}
#
#
# Date: 2023-11-02 03:00:00
# Données météorologiques: {'dt': 1698894000, 'main': {'temp': 291.38, 'feels_like': 291.19, 'temp_min': 291.38, 'temp_max': 291.38, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 1011, 'humidity': 74, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 0.75, 'deg': 64, 'gust': 0.78}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-02 03:00:00'}
#
#
# Date: 2023-11-02 06:00:00
# Données météorologiques: {'dt': 1698904800, 'main': {'temp': 291.13, 'feels_like': 290.92, 'temp_min': 291.13, 'temp_max': 291.13, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 1011, 'humidity': 74, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 1}, 'wind': {'speed': 1.13, 'deg': 220, 'gust': 1.26}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-02 06:00:00'}
#
#
# Date: 2023-11-02 09:00:00
# Données météorologiques: {'dt': 1698915600, 'main': {'temp': 292.93, 'feels_like': 292.74, 'temp_min': 292.93, 'temp_max': 292.93, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 1012, 'humidity': 68, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'clouds': {'all': 0}, 'wind': {'speed': 4.05, 'deg': 213, 'gust': 4.89}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2023-11-02 09:00:00'}
#
#
# Prévisions météorologiques pour Marrakech pour les prochains 5 jours:
# Date: 2023-11-01 21:00:00
# Données météorologiques: {'dt': 1698872400, 'main': {'temp': 297.51, 'feels_like': 297.23, 'temp_min': 296.14, 'temp_max': 297.51, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 968, 'humidity': 47, 'temp_kf': 1.37}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 2.33, 'deg': 34, 'gust': 3.44}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-01 21:00:00'}
#
#
# Date: 2023-11-02 00:00:00
# Données météorologiques: {'dt': 1698883200, 'main': {'temp': 295.12, 'feels_like': 294.91, 'temp_min': 293.58, 'temp_max': 295.12, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 968, 'humidity': 59, 'temp_kf': 1.54}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 1.34, 'deg': 13, 'gust': 2.39}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-02 00:00:00'}
#
#
# Date: 2023-11-02 03:00:00
# Données météorologiques: {'dt': 1698894000, 'main': {'temp': 292.23, 'feels_like': 292.07, 'temp_min': 292.23, 'temp_max': 292.23, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 967, 'humidity': 72, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 0.31, 'deg': 360, 'gust': 0.78}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-02 03:00:00'}
#
#
# Date: 2023-11-02 06:00:00
# Données météorologiques: {'dt': 1698904800, 'main': {'temp': 291.22, 'feels_like': 291.12, 'temp_min': 291.22, 'temp_max': 291.22, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 967, 'humidity': 78, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 1.54, 'deg': 304, 'gust': 1.79}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-02 06:00:00'}
#
#
# Date: 2023-11-02 09:00:00
# Données météorologiques: {'dt': 1698915600, 'main': {'temp': 293.61, 'feels_like': 293.46, 'temp_min': 293.61, 'temp_max': 293.61, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 969, 'humidity': 67, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'clouds': {'all': 0}, 'wind': {'speed': 0.95, 'deg': 236, 'gust': 1.14}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2023-11-02 09:00:00'}
#
#
# Prévisions météorologiques pour Fes pour les prochains 5 jours:
# Date: 2023-11-01 21:00:00
# Données météorologiques: {'dt': 1698872400, 'main': {'temp': 293.32, 'feels_like': 293.4, 'temp_min': 293.32, 'temp_max': 293.37, 'pressure': 1022, 'sea_level': 1022, 'grnd_level': 975, 'humidity': 77, 'temp_kf': -0.05}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'clouds': {'all': 27}, 'wind': {'speed': 1.29, 'deg': 244, 'gust': 1.49}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-01 21:00:00'}
#
#
# Date: 2023-11-02 00:00:00
# Données météorologiques: {'dt': 1698883200, 'main': {'temp': 292.68, 'feels_like': 292.67, 'temp_min': 292.37, 'temp_max': 292.68, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 974, 'humidity': 76, 'temp_kf': 0.31}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'clouds': {'all': 13}, 'wind': {'speed': 0.96, 'deg': 305, 'gust': 0.99}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-02 00:00:00'}
#
#
# Date: 2023-11-02 03:00:00
# Données météorologiques: {'dt': 1698894000, 'main': {'temp': 291.15, 'feels_like': 291.04, 'temp_min': 291.15, 'temp_max': 291.15, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 973, 'humidity': 78, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 1.42, 'deg': 296, 'gust': 1.6}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-02 03:00:00'}
#
#
# Date: 2023-11-02 06:00:00
# Données météorologiques: {'dt': 1698904800, 'main': {'temp': 290.35, 'feels_like': 290.21, 'temp_min': 290.35, 'temp_max': 290.35, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 973, 'humidity': 80, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 1}, 'wind': {'speed': 1.64, 'deg': 302, 'gust': 1.98}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-02 06:00:00'}
#
#
# Date: 2023-11-02 09:00:00
# Données météorologiques: {'dt': 1698915600, 'main': {'temp': 292.37, 'feels_like': 292.2, 'temp_min': 292.37, 'temp_max': 292.37, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 974, 'humidity': 71, 'temp_kf': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'clouds': {'all': 0}, 'wind': {'speed': 1.97, 'deg': 291, 'gust': 3.16}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2023-11-02 09:00:00'}
# Prévisions météorologiques pour Tangier pour les prochains 5 jours:
# Date: 2023-11-01 21:00:00
# Données météorologiques: {'dt': 1698872400, 'main': {'temp': 291.63, 'feels_like': 291.7, 'temp_min': 291.31, 'temp_max': 291.63, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 1013, 'humidity': 83, 'temp_kf': 0.32}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 2}, 'wind': {'speed': 1.79, 'deg': 250, 'gust': 2.8}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-01 21:00:00'}
#
#
# Date: 2023-11-02 00:00:00
# Données météorologiques: {'dt': 1698883200, 'main': {'temp': 291.06, 'feels_like': 291.05, 'temp_min': 290.7, 'temp_max': 291.06, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 1013, 'humidity': 82, 'temp_kf': 0.36}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 3}, 'wind': {'speed': 2.7, 'deg': 231, 'gust': 4.45}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-02 00:00:00'}
#
#
# Date: 2023-11-02 03:00:00
# Données météorologiques: {'dt': 1698894000, 'main': {'temp': 290.41, 'feels_like': 290.36, 'temp_min': 290.41, 'temp_max': 290.41, 'pressure': 1019, 'sea_level': 1019, 'grnd_level': 1011, 'humidity': 83, 'temp_kf': 0}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'clouds': {'all': 29}, 'wind': {'speed': 3.99, 'deg': 227, 'gust': 6.88}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-02 03:00:00'}
#
#
# Date: 2023-11-02 06:00:00
# Données météorologiques: {'dt': 1698904800, 'main': {'temp': 290.24, 'feels_like': 290.2, 'temp_min': 290.24, 'temp_max': 290.24, 'pressure': 1018, 'sea_level': 1018, 'grnd_level': 1010, 'humidity': 84, 'temp_kf': 0}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'clouds': {'all': 16}, 'wind': {'speed': 6.1, 'deg': 215, 'gust': 10.74}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-11-02 06:00:00'}
#
#
# Date: 2023-11-02 09:00:00
# Données météorologiques: {'dt': 1698915600, 'main': {'temp': 292.16, 'feels_like': 292.1, 'temp_min': 292.16, 'temp_max': 292.16, 'pressure': 1018, 'sea_level': 1018, 'grnd_level': 1010, 'humidity': 76, 'temp_kf': 0}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'clouds': {'all': 34}, 'wind': {'speed': 8.67, 'deg': 221, 'gust': 13.09}, 'visibility': 10000, 'pop': 0.06, 'sys': {'pod': 'd'}, 'dt_txt': '2023-11-02 09:00:00'}
